# %% [markdown]
# <a href="https://colab.research.google.com/github/MohuaSinha/EVA4/blob/master/S13/S13_YoloV3_FaceMask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla K80', major=3, minor=7, total_memory=11441MB, multi_processor_count=13)

# %%
# %cd "//content/gdrive/My Drive/Colab Notebooks/EVA4/S13"
import sys
workingdir = '/content/gdrive/My Drive/Colab Notebooks/EVA4/S13'
sys.path.append(workingdir)
# Out:
# /content/gdrive/My Drive/Colab Notebooks/EVA4/S13

# %%
#!git clone https://github.com/theschoolofai/YoloV3.git

# %%
ls
# Out:
# 500_images_surgical_mask.zip  S13_YoloV3.ipynb  YoloV3/

# %%
cd YoloV3/
# Out:
# /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   out_out	  results.png  'ubdivisions=1'
#  cfg		   output	  runs	        utils
#  data		   __pycache__	  test.py       vim.exe.stackdump
#  detect.py	   README.md	  ting	        weights
#  models.py	   results.json   train.py

# %%
cd /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/YoloV3
# Out:
# /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/YoloV3

# %%
ls
# Out:
#  annotation_tool/   out_out/       results.png  'ubdivisions=1'
#  cfg/               output/        runs/         utils/
#  data/              __pycache__/   test.py       vim.exe.stackdump
#  detect.py          README.md      ting          weights/
#  models.py          results.json   train.py

# %%
#!git clone https://github.com/miki998/YoloV3_Annotation_Tool.git

# %%
#!python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 1 --nosave

# %%
# !python train.py --data data/customdata/custom.data --batch 15 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=15, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# 2020-04-25 18:39:15.405868: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (131 found, 0 missing, 0 empty, 0 duplicate, for 131 images): 100% 131/131 [00:48<00:00,  2.70it/s]
# Caching images (0.1GB): 100% 131/131 [00:30<00:00,  4.29it/s]
# Reading image shapes: 100% 131/131 [00:00<00:00, 758.34it/s]
# ...

# %%
#cd data/customdata1
#ls

# %%
# !python detect.py --source MaskForce.mp4 --conf-thres 0.1 --output vid
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# image 1/131 data/customdata/images/facemask_1.jpg: 512x512 1 facemasks, Done. (0.104s)
# image 2/131 data/customdata/images/facemask_10.jpg: 512x512 1 facemasks, Done. (0.095s)
# image 3/131 data/customdata/images/facemask_100.jpg: 512x512 1 facemasks, Done. (0.090s)
# image 4/131 data/customdata/images/facemask_101.jpg: 512x512 1 facemasks, Done. (0.086s)
# image 5/131 data/customdata/images/facemask_102.jpg: 512x512 1 facemasks, Done. (0.083s)
# ...

# %%
ls
# Out:
#  annotation_tool/   out_out/       results.txt        train.py
#  cfg/               output/        runs/             'ubdivisions=1'
#  data/              __pycache__/   test_batch0.png    utils/
#  detect.py          README.md      test.py            vim.exe.stackdump
#  MaskForce.mp4      results.json   ting               weights/
#  models.py          results.png    train_batch0.png

# %%
# !python detect.py  --weights weights/last.pt --cfg "cfg/yolov3-custom.cfg" --names data/customdata/custom.names --source "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/YoloV3/InputVideo/TeamMaskForce _ Sachin Tendulkar.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='output', save_txt=False, source='/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/YoloV3/InputVideo/TeamMaskForce _ Sachin Tendulkar.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/1028) /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/YoloV3/InputVideo/TeamMaskForce _ Sachin Tendulkar.mp4: 320x512 1 facemasks, Done. (0.087s)
# video 1/1 (2/1028) /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/YoloV3/InputVideo/TeamMaskForce _ Sachin Tendulkar.mp4: 320x512 1 facemasks, Done. (0.076s)
# ...

# %%
Image(filename='out_out/facemask_1.jpg', width=600)
