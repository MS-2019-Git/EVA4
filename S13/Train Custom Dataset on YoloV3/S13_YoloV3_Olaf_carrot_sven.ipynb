# %% [markdown]
# <a href="https://colab.research.google.com/github/MohuaSinha/EVA4/blob/master/S13/S13_YoloV3_Olaf_carrot_sven.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
# %cd "//content/gdrive/My Drive/Colab Notebooks/EVA4/S13"
import sys
workingdir = '/content/gdrive/My Drive/Colab Notebooks/EVA4/S13'
sys.path.append(workingdir)
# Out:
# /content/gdrive/My Drive/Colab Notebooks/EVA4/S13

# %%
#!git clone https://github.com/theschoolofai/YoloV3.git

# %%
cd /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/YoloV3
# Out:
# /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/YoloV3

# %%
ls
# Out:
#  annotation_tool/   out_out/       results.txt        train.py
#  cfg/               output/        runs/             'ubdivisions=1'
#  data/              __pycache__/   test_batch0.png    utils/
#  detect.py          README.md      test.py           'videos_face mask'/
#  InputVideo/        results.json   ting               vim.exe.stackdump
#  models.py          results.png    train_batch0.png   weights/

# %%
#!git clone https://github.com/miki998/YoloV3_Annotation_Tool.git

# %%
#!python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 1 --nosave

# %%
# !python train.py --data data/customdata/custom.data --batch 15 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=15, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-26 10:24:17.617351: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25841e+07 parameters, 6.25841e+07 gradients
# Caching labels (181 found, 0 missing, 0 empty, 0 duplicate, for 181 images): 100% 181/181 [01:27<00:00,  2.07it/s]
# Caching images (0.1GB): 100% 181/181 [01:29<00:00,  2.01it/s]
# Reading image shapes: 100% 181/181 [00:00<00:00, 809.57it/s]
# ...

# %%
# !python detect.py --conf-thres 0.1 --output out_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25841e+07 parameters, 6.25841e+07 gradients
# image 1/181 data/customdata/images/olaf_1.jpg: 512x512 1 olafs, Done. (0.019s)
# image 2/181 data/customdata/images/olaf_10.jpg: 512x512 2 olafs, Done. (0.021s)
# image 3/181 data/customdata/images/olaf_11.jpg: 512x512 1 olafs, Done. (0.020s)
# image 4/181 data/customdata/images/olaf_12.jpg: 512x512 1 olafs, Done. (0.019s)
# image 5/181 data/customdata/images/olaf_13.jpg: 512x512 1 olafs, Done. (0.019s)
# image 6/181 data/customdata/images/olaf_14.jpg: 512x512 1 olafs, Done. (0.019s)
# ...

# %%
Image(filename='out_out/olaf_1.jpg', width=600)

# %%
Image(filename='out_out/olaf_23.jpg', width=600)

# %%
Image(filename='out_out/sven_11.jpg', width=600)

# %%
Image(filename='out_out/sven_50.jpg', width=500)

# %%
# !python detect.py  --weights weights/last.pt --cfg "cfg/yolov3-custom.cfg" --names data/customdata/custom.names --source "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/YoloV3/InputVideo/Disney's frozen hd teaser trailer.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='output', save_txt=False, source="/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/YoloV3/InputVideo/Disney's frozen hd teaser trailer.mp4", view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25841e+07 parameters, 6.25841e+07 gradients
# video 1/1 (1/2702) /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/YoloV3/InputVideo/Disney's frozen hd teaser trailer.mp4: 320x512 Done. (0.019s)
# video 1/1 (2/2702) /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/YoloV3/InputVideo/Disney's frozen hd teaser trailer.mp4: 320x512 Done. (0.022s)
# ...
